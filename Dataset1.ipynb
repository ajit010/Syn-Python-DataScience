# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("students_scores.csv")

# %%
df.mean()
df.median()
df.mode()

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
outliers = df[(df < (Q1 - 1.5*IQR)) | (df > (Q3 + 1.5*IQR))]
